# %%
import spacy
import nltk
import re
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from collections import Counter

# %%
## Ensure necessary downloads
# nltk.download('vader_lexicon')
# nltk.download('punkt')
# nltk.download('punkt_tab')
# !python -m spacy download en_core_web_md

# %%
def get_processed_text(text):
  text = re.sub(r'[^\w\s]', '', text)
  return text.lower()

def get_polarity_scores(text):
  sia = SentimentIntensityAnalyzer()
  return sia.polarity_scores(text)

def get_named_entities(text):
  nlp = spacy.load("en_core_web_md")
  doc = nlp(text)
  return [(ent.text, ent.label_) for ent in doc.ents]

def get_key_themes(text):
  tokens = word_tokenize(text)
  return [word for word, count in Counter(tokens).most_common(3)]

def get_patterns(text):
  processed_text = get_processed_text(text)
  sentiment_score = get_polarity_scores(processed_text)
  entities = get_named_entities(processed_text)
  keywords = get_key_themes(processed_text)
  return {
      "text": text,
      "sentiment": sentiment_score,
      "entities": entities,
      "key_themes": keywords
      }

# %%
# For easy evaluation, i am using top 100 statements from a open source dataset.

feedback_statements = [
    "I purchased an iPhone 15 from Apple last week, and the camera quality is amazing!",
    "The delivery of my Samsung Galaxy S23 was delayed by Amazon by three days.",
    "The customer support team at Microsoft resolved my issue quickly.",
    "I visited the Tesla showroom in New York and loved the Model X features.",
    "The battery life of my Dell laptop is significantly shorter than expected.",
    "I had a terrible experience at Starbucks in Los Angeles due to poor service.",
    "The warranty policy for Sony headphones should be clearer on the website.",
    "My order from Flipkart was misplaced, and I had to contact customer service.",
    "I ordered Nike running shoes from their website, but they sent the wrong size.",
    "The chat support on Netflix was very helpful when I had billing issues.",
    "My flight with Emirates from Dubai to London was delayed by four hours.",
    "The pricing model of Adobe Photoshop is confusing for new users.",
    "Uber’s surge pricing in San Francisco makes rides extremely expensive.",
    "The return policy of Amazon for damaged items needs to be more flexible.",
    "I received a defective HP printer, and the replacement took weeks to arrive.",
    "The customer service representative at Lenovo was knowledgeable and polite.",
    "Booking a ticket through Expedia for my trip to Paris was seamless.",
    "The Spotify premium subscription offers great music recommendations.",
    "My parcel from FedEx was delivered to the wrong address in Chicago.",
    "The speed of 5G on my OnePlus smartphone is impressive compared to 4G.",
    "My visit to Disneyland in California was magical, but the ticket prices are high.",
    "I need better clarification on Google's privacy policy for my Gmail account.",
    "The Marriott hotel in New York provided excellent hospitality during my stay.",
    "The display quality of the Samsung QLED TV is phenomenal.",
    "I was disappointed with the service at Domino’s Pizza in Miami.",
    "The security features of PayPal make online transactions safer.",
    "My Lyft ride in Houston was comfortable, but the driver took a longer route.",
    "The touchscreen of my Asus ZenBook is not responding properly.",
    "My banking experience with Citibank has been smooth, except for occasional app crashes.",
    "The UI of Airbnb’s app is user-friendly for booking properties worldwide.",
    "The freshness of groceries delivered by Instacart in Seattle is inconsistent.",
    "Apple’s Face ID security feature works seamlessly on my iPhone.",
    "The luggage handling at British Airways needs significant improvement.",
    "The PlayStation 5 gaming experience is incredible compared to older versions.",
    "The food quality at McDonald's in Toronto was surprisingly better this time.",
    "Booking train tickets via IRCTC was confusing due to unclear navigation.",
    "The packaging of my Xiaomi smartphone was damaged upon arrival.",
    "I faced frequent crashes while using Zoom for my online meetings.",
    "The check-in process at Hyatt hotels needs streamlining for international travelers.",
    "My Bose earbuds are excellent, but the battery drains too quickly.",
    "The notifications in the Slack app for work updates are useful.",
    "The clothing collection at Zara has great designs but limited size availability.",
    "My experience with Uber Eats in Chicago was frustrating due to delayed food delivery.",
    "The refund process for cancelled Southwest Airlines flights is slow.",
    "The warranty coverage for LG refrigerators should be expanded to more regions.",
    "The ride-sharing options with Ola in India are cheaper than competitors.",
    "The durability of my Timex watch is remarkable.",
    "The recommendation algorithm on Amazon suggests great products.",
    "My insurance claim with Geico was processed faster than I expected.",
    "The process of subscribing to The New York Times digital edition is smooth.",
    "The camera resolution of Google Pixel smartphones is outstanding.",
    "My WiFi speed with Verizon fluctuates during peak hours.",
    "Booking a rental car through Hertz was convenient and affordable.",
    "The keyboard quality on my Logitech gaming setup is superb.",
    "My Netflix subscription auto-renewed without prior notification.",
    "The cashback offers on American Express credit cards are valuable.",
    "The time tracking feature in Trello helps with productivity management.",
    "I faced authentication issues while logging into my Dropbox account.",
    "The variety of shows on Hulu has significantly improved this year.",
    "My Uber driver in Tokyo was extremely courteous and helpful.",
    "The checkout process on Best Buy’s website should be more intuitive.",
    "I received great assistance at the Vodafone store while changing plans.",
    "The variety of beauty products on Sephora's website is extensive.",
    "The Samsung Galaxy Watch battery lasts longer than expected.",
    "The promotions on Macy’s online store helped me save a lot on my purchases.",
    "My subscription to Grammarly improved my writing quality noticeably.",
    "The coffee blend at Dunkin’ Donuts is my favorite.",
    "The ticket pricing structure of Universal Studios in Orlando is overpriced.",
    "I faced login failures while trying to access my LinkedIn account.",
    "The mobile banking app by Chase Bank is convenient for transactions.",
    "The resolution of my Dell monitor makes working more comfortable.",
    "I faced difficulty configuring my Cisco router settings.",
    "The search feature on Pinterest gives highly relevant results.",
    "My Uber Eats order arrived cold and was not properly sealed.",
    "Booking hotels via Agoda has given me great discounts.",
    "The color accuracy of the Asus VivoBook screen is impressive.",
    "My luggage with Lufthansa Airlines was delayed for three days.",
    "The subscription model for Coursera courses is affordable.",
    "The audio quality of JBL speakers is amazing for parties.",
    "The interface of Duolingo for learning languages is fun and interactive.",
    "My Xiaomi Redmi phone keeps heating up during gaming sessions.",
    "The packaging for my Apple AirPods was eco-friendly.",
    "The shopping experience at Walmart online was fast and reliable.",
    "The UI of Google Drive makes file sharing effortless.",
    "My Uber driver in London followed all safety protocols.",
    "The product catalog at Etsy has unique handmade items.",
    "My Zoom call quality was poor due to unstable internet connectivity.",
    "The analytics dashboard on Shopify gives useful business insights.",
    "The refund policy on AliExpress needs to be more customer-friendly.",
    "My Paytm transaction got stuck due to verification delays.",
    "The responsiveness of the Tesla autopilot feature is incredible.",
    "The navigation features in Google Maps helped me during my trip.",
    "My reservation with Booking.com was canceled without notification.",
    "The discounts on Priceline hotel bookings saved me a lot of money.",
    "The performance of my Intel-powered laptop is smooth.",
    "The smartwatch collection at Fossil offers stylish designs.",
    "The cloud storage features in OneDrive are secure.",
    "The delivery tracking on FedEx’s website is real-time and efficient.",
    "The Twitter algorithm shows me relevant trending topics.",
    "My 4G connection on Jio telecom dropped frequently in rural areas."
]

# %%
df = pd.DataFrame(feedback_statements, columns=["Feedback"])
df["Patterns"] = df["Feedback"].apply(get_patterns)

# %%
pd.set_option('display.max_colwidth', None)

df.head(100)
# Out:
#                                                                                    Feedback  \
# 0         I purchased an iPhone 15 from Apple last week, and the camera quality is amazing!
# 1                The delivery of my Samsung Galaxy S23 was delayed by Amazon by three days.
# 2                         The customer support team at Microsoft resolved my issue quickly.
# 3                  I visited the Tesla showroom in New York and loved the Model X features.
# 4                The battery life of my Dell laptop is significantly shorter than expected.
# 5              I had a terrible experience at Starbucks in Los Angeles due to poor service.
# 6                 The warranty policy for Sony headphones should be clearer on the website.
# 7              My order from Flipkart was misplaced, and I had to contact customer service.
# 8            I ordered Nike running shoes from their website, but they sent the wrong size.
# 9                   The chat support on Netflix was very helpful when I had billing issues.
# 10                  My flight with Emirates from Dubai to London was delayed by four hours.
# 11                         The pricing model of Adobe Photoshop is confusing for new users.
# 12                   Uber’s surge pricing in San Francisco makes rides extremely expensive.
# 13                 The return policy of Amazon for damaged items needs to be more flexible.
# 14             I received a defective HP printer, and the replacement took weeks to arrive.
# 15              The customer service representative at Lenovo was knowledgeable and polite.
# 16                      Booking a ticket through Expedia for my trip to Paris was seamless.
# 17                     The Spotify premium subscription offers great music recommendations.
# 18                      My parcel from FedEx was delivered to the wrong address in Chicago.
# 19                   The speed of 5G on my OnePlus smartphone is impressive compared to 4G.
# 20        My visit to Disneyland in California was magical, but the ticket prices are high.
# 21             I need better clarification on Google's privacy policy for my Gmail account.
# 22            The Marriott hotel in New York provided excellent hospitality during my stay.
# 23                                The display quality of the Samsung QLED TV is phenomenal.
# 24                          I was disappointed with the service at Domino’s Pizza in Miami.
# 25                          The security features of PayPal make online transactions safer.
# 26             My Lyft ride in Houston was comfortable, but the driver took a longer route.
# 27                           The touchscreen of my Asus ZenBook is not responding properly.
# 28  My banking experience with Citibank has been smooth, except for occasional app crashes.
# 29                The UI of Airbnb’s app is user-friendly for booking properties worldwide.
# 30            The freshness of groceries delivered by Instacart in Seattle is inconsistent.
# 31                          Apple’s Face ID security feature works seamlessly on my iPhone.
# 32                   The luggage handling at British Airways needs significant improvement.
# 33            The PlayStation 5 gaming experience is incredible compared to older versions.
# 34             The food quality at McDonald's in Toronto was surprisingly better this time.
# 35                 Booking train tickets via IRCTC was confusing due to unclear navigation.
# 36                          The packaging of my Xiaomi smartphone was damaged upon arrival.
# 37                        I faced frequent crashes while using Zoom for my online meetings.
# 38     The check-in process at Hyatt hotels needs streamlining for international travelers.
# 39                       My Bose earbuds are excellent, but the battery drains too quickly.
# 40                          The notifications in the Slack app for work updates are useful.
# 41         The clothing collection at Zara has great designs but limited size availability.
# 42    My experience with Uber Eats in Chicago was frustrating due to delayed food delivery.
# 43                     The refund process for cancelled Southwest Airlines flights is slow.
# 44           The warranty coverage for LG refrigerators should be expanded to more regions.
# 45                 The ride-sharing options with Ola in India are cheaper than competitors.
# 46                                          The durability of my Timex watch is remarkable.
# 47                          The recommendation algorithm on Amazon suggests great products.
# 48                      My insurance claim with Geico was processed faster than I expected.
# 49              The process of subscribing to The New York Times digital edition is smooth.
# 50                        The camera resolution of Google Pixel smartphones is outstanding.
# 51                                 My WiFi speed with Verizon fluctuates during peak hours.
# 52                        Booking a rental car through Hertz was convenient and affordable.
# 53                              The keyboard quality on my Logitech gaming setup is superb.
# 54                         My Netflix subscription auto-renewed without prior notification.
# 55                       The cashback offers on American Express credit cards are valuable.
# 56                  The time tracking feature in Trello helps with productivity management.
# 57                     I faced authentication issues while logging into my Dropbox account.
# 58                       The variety of shows on Hulu has significantly improved this year.
# 59                             My Uber driver in Tokyo was extremely courteous and helpful.
# 60                     The checkout process on Best Buy’s website should be more intuitive.
# 61                  I received great assistance at the Vodafone store while changing plans.
# 62                        The variety of beauty products on Sephora's website is extensive.
# 63                             The Samsung Galaxy Watch battery lasts longer than expected.
# 64              The promotions on Macy’s online store helped me save a lot on my purchases.
# 65                     My subscription to Grammarly improved my writing quality noticeably.
# 66                                       The coffee blend at Dunkin’ Donuts is my favorite.
# 67              The ticket pricing structure of Universal Studios in Orlando is overpriced.
# 68                       I faced login failures while trying to access my LinkedIn account.
# 69                     The mobile banking app by Chase Bank is convenient for transactions.
# 70                        The resolution of my Dell monitor makes working more comfortable.
# 71                                 I faced difficulty configuring my Cisco router settings.
# 72                           The search feature on Pinterest gives highly relevant results.
# 73                             My Uber Eats order arrived cold and was not properly sealed.
# 74                                   Booking hotels via Agoda has given me great discounts.
# 75                            The color accuracy of the Asus VivoBook screen is impressive.
# 76                           My luggage with Lufthansa Airlines was delayed for three days.
# 77                               The subscription model for Coursera courses is affordable.
# 78                                The audio quality of JBL speakers is amazing for parties.
# 79                 The interface of Duolingo for learning languages is fun and interactive.
# 80                           My Xiaomi Redmi phone keeps heating up during gaming sessions.
# 81                                     The packaging for my Apple AirPods was eco-friendly.
# 82                         The shopping experience at Walmart online was fast and reliable.
# 83                                    The UI of Google Drive makes file sharing effortless.
# 84                                  My Uber driver in London followed all safety protocols.
# 85                                   The product catalog at Etsy has unique handmade items.
# 86                     My Zoom call quality was poor due to unstable internet connectivity.
# 87                       The analytics dashboard on Shopify gives useful business insights.
# 88                      The refund policy on AliExpress needs to be more customer-friendly.
# 89                               My Paytm transaction got stuck due to verification delays.
# 90                         The responsiveness of the Tesla autopilot feature is incredible.
# 91                         The navigation features in Google Maps helped me during my trip.
# 92                       My reservation with Booking.com was canceled without notification.
# 93                       The discounts on Priceline hotel bookings saved me a lot of money.
# 94                                    The performance of my Intel-powered laptop is smooth.
# 95                              The smartwatch collection at Fossil offers stylish designs.
# 96                                       The cloud storage features in OneDrive are secure.
# 97                     The delivery tracking on FedEx’s website is real-time and efficient.
# 98                                 The Twitter algorithm shows me relevant trending topics.
# 99                       My 4G connection on Jio telecom dropped frequently in rural areas.
#
#                                                                                                                                                                                                                                                                                                    Patterns
# 0                                 {'text': 'I purchased an iPhone 15 from Apple last week, and the camera quality is amazing!', 'sentiment': {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.5859}, 'entities': [('15', 'CARDINAL'), ('last week', 'DATE')], 'key_themes': ['i', 'purchased', 'an']}
# 1                {'text': 'The delivery of my Samsung Galaxy S23 was delayed by Amazon by three days.', 'sentiment': {'neg': 0.122, 'neu': 0.769, 'pos': 0.109, 'compound': -0.0516}, 'entities': [('samsung', 'ORG'), ('amazon', 'ORG'), ('three days', 'DATE')], 'key_themes': ['by', 'the', 'delivery']}
# 2                                                                {'text': 'The customer support team at Microsoft resolved my issue quickly.', 'sentiment': {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.5267}, 'entities': [('microsoft', 'ORG')], 'key_themes': ['the', 'customer', 'support']}
# 3                                                                 {'text': 'I visited the Tesla showroom in New York and loved the Model X features.', 'sentiment': {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.5994}, 'entities': [('new york', 'GPE')], 'key_themes': ['the', 'i', 'visited']}
# 4                                                                                      {'text': 'The battery life of my Dell laptop is significantly shorter than expected.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'battery', 'life']}
# 5                                                               {'text': 'I had a terrible experience at Starbucks in Los Angeles due to poor service.', 'sentiment': {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'compound': -0.7351}, 'entities': [('los angeles', 'GPE')], 'key_themes': ['i', 'had', 'a']}
# 6                                                                     {'text': 'The warranty policy for Sony headphones should be clearer on the website.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('sony', 'ORG')], 'key_themes': ['the', 'warranty', 'policy']}
# 7                                                                                       {'text': 'My order from Flipkart was misplaced, and I had to contact customer service.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['my', 'order', 'from']}
# 8                                                              {'text': 'I ordered Nike running shoes from their website, but they sent the wrong size.', 'sentiment': {'neg': 0.257, 'neu': 0.743, 'pos': 0.0, 'compound': -0.631}, 'entities': [('nike', 'ORG')], 'key_themes': ['i', 'ordered', 'nike']}
# 9                                                                {'text': 'The chat support on Netflix was very helpful when I had billing issues.', 'sentiment': {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.6997}, 'entities': [('netflix', 'ORG')], 'key_themes': ['the', 'chat', 'support']}
# 10  {'text': 'My flight with Emirates from Dubai to London was delayed by four hours.', 'sentiment': {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'compound': -0.2263}, 'entities': [('emirates', 'GPE'), ('dubai', 'GPE'), ('london', 'GPE'), ('four hours', 'TIME')], 'key_themes': ['my', 'flight', 'with']}
# 11                                                                                        {'text': 'The pricing model of Adobe Photoshop is confusing for new users.', 'sentiment': {'neg': 0.16, 'neu': 0.84, 'pos': 0.0, 'compound': -0.2263}, 'entities': [], 'key_themes': ['the', 'pricing', 'model']}
# 12                                                              {'text': 'Uber’s surge pricing in San Francisco makes rides extremely expensive.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('san francisco', 'GPE')], 'key_themes': ['ubers', 'surge', 'pricing']}
# 13                                                           {'text': 'The return policy of Amazon for damaged items needs to be more flexible.', 'sentiment': {'neg': 0.173, 'neu': 0.595, 'pos': 0.232, 'compound': -0.0018}, 'entities': [('amazon', 'ORG')], 'key_themes': ['the', 'return', 'policy']}
# 14                                                              {'text': 'I received a defective HP printer, and the replacement took weeks to arrive.', 'sentiment': {'neg': 0.225, 'neu': 0.775, 'pos': 0.0, 'compound': -0.4404}, 'entities': [('weeks', 'DATE')], 'key_themes': ['i', 'received', 'a']}
# 15                                                               {'text': 'The customer service representative at Lenovo was knowledgeable and polite.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('lenovo', 'ORG')], 'key_themes': ['the', 'customer', 'service']}
# 16                                                                            {'text': 'Booking a ticket through Expedia for my trip to Paris was seamless.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('paris', 'GPE')], 'key_themes': ['booking', 'a', 'ticket']}
# 17                                          {'text': 'The Spotify premium subscription offers great music recommendations.', 'sentiment': {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6249}, 'entities': [('spotify premium subscription', 'ORG')], 'key_themes': ['the', 'spotify', 'premium']}
# 18                                                                      {'text': 'My parcel from FedEx was delivered to the wrong address in Chicago.', 'sentiment': {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.4767}, 'entities': [('chicago', 'GPE')], 'key_themes': ['my', 'parcel', 'from']}
# 19                                                  {'text': 'The speed of 5G on my OnePlus smartphone is impressive compared to 4G.', 'sentiment': {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'compound': 0.5106}, 'entities': [('5', 'CARDINAL'), ('4', 'CARDINAL')], 'key_themes': ['the', 'speed', 'of']}
# 20                                       {'text': 'My visit to Disneyland in California was magical, but the ticket prices are high.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('disneyland', 'FAC'), ('california', 'GPE')], 'key_themes': ['my', 'visit', 'to']}
# 21                                                                               {'text': 'I need better clarification on Google's privacy policy for my Gmail account.', 'sentiment': {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}, 'entities': [], 'key_themes': ['i', 'need', 'better']}
# 22                       {'text': 'The Marriott hotel in New York provided excellent hospitality during my stay.', 'sentiment': {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.5719}, 'entities': [('the marriott hotel', 'ORG'), ('new york', 'GPE')], 'key_themes': ['the', 'marriott', 'hotel']}
# 23                                                                                                   {'text': 'The display quality of the Samsung QLED TV is phenomenal.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'display', 'quality']}
# 24                                                  {'text': 'I was disappointed with the service at Domino’s Pizza in Miami.', 'sentiment': {'neg': 0.256, 'neu': 0.744, 'pos': 0.0, 'compound': -0.4767}, 'entities': [('dominos', 'ORG'), ('miami', 'GPE')], 'key_themes': ['i', 'was', 'disappointed']}
# 25                                                                                    {'text': 'The security features of PayPal make online transactions safer.', 'sentiment': {'neg': 0.0, 'neu': 0.574, 'pos': 0.426, 'compound': 0.6369}, 'entities': [], 'key_themes': ['the', 'security', 'features']}
# 26                                                              {'text': 'My Lyft ride in Houston was comfortable, but the driver took a longer route.', 'sentiment': {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.2846}, 'entities': [('houston', 'GPE')], 'key_themes': ['my', 'lyft', 'ride']}
# 27                                                                                               {'text': 'The touchscreen of my Asus ZenBook is not responding properly.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'touchscreen', 'of']}
# 28                                                {'text': 'My banking experience with Citibank has been smooth, except for occasional app crashes.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('citibank', 'ORG')], 'key_themes': ['my', 'banking', 'experience']}
# 29                                                                                             {'text': 'The UI of Airbnb’s app is user-friendly for booking properties worldwide.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'ui', 'of']}
# 30                                          {'text': 'The freshness of groceries delivered by Instacart in Seattle is inconsistent.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('instacart', 'ORG'), ('seattle', 'GPE')], 'key_themes': ['the', 'freshness', 'of']}
# 31                                                                                             {'text': 'Apple’s Face ID security feature works seamlessly on my iPhone.', 'sentiment': {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.34}, 'entities': [], 'key_themes': ['apples', 'face', 'id']}
# 32                                                    {'text': 'The luggage handling at British Airways needs significant improvement.', 'sentiment': {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'compound': 0.5859}, 'entities': [('british airways', 'ORG')], 'key_themes': ['the', 'luggage', 'handling']}
# 33                                                                {'text': 'The PlayStation 5 gaming experience is incredible compared to older versions.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('5', 'CARDINAL')], 'key_themes': ['the', 'playstation', '5']}
# 34                                    {'text': 'The food quality at McDonald's in Toronto was surprisingly better this time.', 'sentiment': {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.6249}, 'entities': [('mcdonalds', 'ORG'), ('toronto', 'GPE')], 'key_themes': ['the', 'food', 'quality']}
# 35                                                                          {'text': 'Booking train tickets via IRCTC was confusing due to unclear navigation.', 'sentiment': {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.4404}, 'entities': [], 'key_themes': ['booking', 'train', 'tickets']}
# 36                                                                                        {'text': 'The packaging of my Xiaomi smartphone was damaged upon arrival.', 'sentiment': {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.4404}, 'entities': [], 'key_themes': ['the', 'packaging', 'of']}
# 37                                                                                              {'text': 'I faced frequent crashes while using Zoom for my online meetings.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['i', 'faced', 'frequent']}
# 38                                                 {'text': 'The check-in process at Hyatt hotels needs streamlining for international travelers.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('hyatt hotels', 'ORG')], 'key_themes': ['the', 'checkin', 'process']}
# 39                                                                                         {'text': 'My Bose earbuds are excellent, but the battery drains too quickly.', 'sentiment': {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compound': 0.3291}, 'entities': [], 'key_themes': ['my', 'bose', 'earbuds']}
# 40                                                                                     {'text': 'The notifications in the Slack app for work updates are useful.', 'sentiment': {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}, 'entities': [], 'key_themes': ['the', 'notifications', 'in']}
# 41                                                {'text': 'The clothing collection at Zara has great designs but limited size availability.', 'sentiment': {'neg': 0.158, 'neu': 0.671, 'pos': 0.171, 'compound': 0.0516}, 'entities': [('zara', 'ORG')], 'key_themes': ['the', 'clothing', 'collection']}
# 42                                              {'text': 'My experience with Uber Eats in Chicago was frustrating due to delayed food delivery.', 'sentiment': {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.5859}, 'entities': [('chicago', 'GPE')], 'key_themes': ['my', 'experience', 'with']}
# 43                                                                                   {'text': 'The refund process for cancelled Southwest Airlines flights is slow.', 'sentiment': {'neg': 0.182, 'neu': 0.818, 'pos': 0.0, 'compound': -0.25}, 'entities': [], 'key_themes': ['the', 'refund', 'process']}
# 44                                                                            {'text': 'The warranty coverage for LG refrigerators should be expanded to more regions.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'warranty', 'coverage']}
# 45                                                {'text': 'The ride-sharing options with Ola in India are cheaper than competitors.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('ola', 'ORG'), ('india', 'GPE')], 'key_themes': ['the', 'ridesharing', 'options']}
# 46                                                                                          {'text': 'The durability of my Timex watch is remarkable.', 'sentiment': {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.5574}, 'entities': [('timex', 'ORG')], 'key_themes': ['the', 'durability', 'of']}
# 47                                                            {'text': 'The recommendation algorithm on Amazon suggests great products.', 'sentiment': {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.7003}, 'entities': [('amazon', 'ORG')], 'key_themes': ['the', 'recommendation', 'algorithm']}
# 48                                                                          {'text': 'My insurance claim with Geico was processed faster than I expected.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('geico', 'ORG')], 'key_themes': ['my', 'insurance', 'claim']}
# 49                                           {'text': 'The process of subscribing to The New York Times digital edition is smooth.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('the new york', 'ORG'), ('digital', 'ORG')], 'key_themes': ['the', 'process', 'of']}
# 50                                                                                  {'text': 'The camera resolution of Google Pixel smartphones is outstanding.', 'sentiment': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6124}, 'entities': [], 'key_themes': ['the', 'camera', 'resolution']}
# 51                                                                                         {'text': 'My WiFi speed with Verizon fluctuates during peak hours.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('hours', 'TIME')], 'key_themes': ['my', 'wifi', 'speed']}
# 52                                                                                              {'text': 'Booking a rental car through Hertz was convenient and affordable.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['booking', 'a', 'rental']}
# 53                                                                                         {'text': 'The keyboard quality on my Logitech gaming setup is superb.', 'sentiment': {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6249}, 'entities': [], 'key_themes': ['the', 'keyboard', 'quality']}
# 54                                                                      {'text': 'My Netflix subscription auto-renewed without prior notification.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('netflix', 'ORG')], 'key_themes': ['my', 'netflix', 'subscription']}
# 55                                                               {'text': 'The cashback offers on American Express credit cards are valuable.', 'sentiment': {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.6908}, 'entities': [('american', 'NORP')], 'key_themes': ['the', 'cashback', 'offers']}
# 56                                                                                {'text': 'The time tracking feature in Trello helps with productivity management.', 'sentiment': {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}, 'entities': [], 'key_themes': ['the', 'time', 'tracking']}
# 57                                                                                     {'text': 'I faced authentication issues while logging into my Dropbox account.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['i', 'faced', 'authentication']}
# 58                                                                   {'text': 'The variety of shows on Hulu has significantly improved this year.', 'sentiment': {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4767}, 'entities': [('this year', 'DATE')], 'key_themes': ['the', 'variety', 'of']}
# 59                                                                              {'text': 'My Uber driver in Tokyo was extremely courteous and helpful.', 'sentiment': {'neg': 0.0, 'neu': 0.546, 'pos': 0.454, 'compound': 0.7688}, 'entities': [('tokyo', 'GPE')], 'key_themes': ['my', 'uber', 'driver']}
# 60                                                                                {'text': 'The checkout process on Best Buy’s website should be more intuitive.', 'sentiment': {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.6369}, 'entities': [], 'key_themes': ['the', 'checkout', 'process']}
# 61                                                                                 {'text': 'I received great assistance at the Vodafone store while changing plans.', 'sentiment': {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6249}, 'entities': [], 'key_themes': ['i', 'received', 'great']}
# 62                                                                                         {'text': 'The variety of beauty products on Sephora's website is extensive.', 'sentiment': {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'compound': 0.5859}, 'entities': [], 'key_themes': ['the', 'variety', 'of']}
# 63                                                                               {'text': 'The Samsung Galaxy Watch battery lasts longer than expected.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('samsung', 'ORG')], 'key_themes': ['the', 'samsung', 'galaxy']}
# 64                                                                            {'text': 'The promotions on Macy’s online store helped me save a lot on my purchases.', 'sentiment': {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.4939}, 'entities': [], 'key_themes': ['on', 'the', 'promotions']}
# 65                                                                                  {'text': 'My subscription to Grammarly improved my writing quality noticeably.', 'sentiment': {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'compound': 0.4767}, 'entities': [], 'key_themes': ['my', 'subscription', 'to']}
# 66                                                                                                      {'text': 'The coffee blend at Dunkin’ Donuts is my favorite.', 'sentiment': {'neg': 0.0, 'neu': 0.727, 'pos': 0.273, 'compound': 0.4588}, 'entities': [], 'key_themes': ['the', 'coffee', 'blend']}
# 67                                                                {'text': 'The ticket pricing structure of Universal Studios in Orlando is overpriced.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('orlando', 'GPE')], 'key_themes': ['the', 'ticket', 'pricing']}
# 68                                                                                          {'text': 'I faced login failures while trying to access my LinkedIn account.', 'sentiment': {'neg': 0.25, 'neu': 0.75, 'pos': 0.0, 'compound': -0.4588}, 'entities': [], 'key_themes': ['i', 'faced', 'login']}
# 69                                                                    {'text': 'The mobile banking app by Chase Bank is convenient for transactions.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('chase bank', 'ORG')], 'key_themes': ['the', 'mobile', 'banking']}
# 70                                                                                      {'text': 'The resolution of my Dell monitor makes working more comfortable.', 'sentiment': {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.5563}, 'entities': [], 'key_themes': ['the', 'resolution', 'of']}
# 71                                                                                               {'text': 'I faced difficulty configuring my Cisco router settings.', 'sentiment': {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.34}, 'entities': [], 'key_themes': ['i', 'faced', 'difficulty']}
# 72                                                                                               {'text': 'The search feature on Pinterest gives highly relevant results.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'search', 'feature']}
# 73                                                                                                       {'text': 'My Uber Eats order arrived cold and was not properly sealed.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['my', 'uber', 'eats']}
# 74                                                                                                {'text': 'Booking hotels via Agoda has given me great discounts.', 'sentiment': {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.6249}, 'entities': [], 'key_themes': ['booking', 'hotels', 'via']}
# 75                                                                                         {'text': 'The color accuracy of the Asus VivoBook screen is impressive.', 'sentiment': {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.5106}, 'entities': [], 'key_themes': ['the', 'color', 'accuracy']}
# 76                                                                    {'text': 'My luggage with Lufthansa Airlines was delayed for three days.', 'sentiment': {'neg': 0.174, 'neu': 0.826, 'pos': 0.0, 'compound': -0.2263}, 'entities': [('three days', 'DATE')], 'key_themes': ['my', 'luggage', 'with']}
# 77                                                                                               {'text': 'The subscription model for Coursera courses is affordable.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'subscription', 'model']}
# 78                                                                                              {'text': 'The audio quality of JBL speakers is amazing for parties.', 'sentiment': {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.7579}, 'entities': [], 'key_themes': ['the', 'audio', 'quality']}
# 79                                                                                {'text': 'The interface of Duolingo for learning languages is fun and interactive.', 'sentiment': {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.5106}, 'entities': [], 'key_themes': ['the', 'interface', 'of']}
# 80                                                                                                  {'text': 'My Xiaomi Redmi phone keeps heating up during gaming sessions.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['my', 'xiaomi', 'redmi']}
# 81                                                                                                          {'text': 'The packaging for my Apple AirPods was eco-friendly.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'packaging', 'for']}
# 82                                                                      {'text': 'The shopping experience at Walmart online was fast and reliable.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('walmart', 'ORG')], 'key_themes': ['the', 'shopping', 'experience']}
# 83                                                                                                          {'text': 'The UI of Google Drive makes file sharing effortless.', 'sentiment': {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}, 'entities': [], 'key_themes': ['the', 'ui', 'of']}
# 84                                                                                  {'text': 'My Uber driver in London followed all safety protocols.', 'sentiment': {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}, 'entities': [('london', 'GPE')], 'key_themes': ['my', 'uber', 'driver']}
# 85                                                                                      {'text': 'The product catalog at Etsy has unique handmade items.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('etsy', 'DATE')], 'key_themes': ['the', 'product', 'catalog']}
# 86                                                                                       {'text': 'My Zoom call quality was poor due to unstable internet connectivity.', 'sentiment': {'neg': 0.384, 'neu': 0.616, 'pos': 0.0, 'compound': -0.6808}, 'entities': [], 'key_themes': ['my', 'zoom', 'call']}
# 87                                                                               {'text': 'The analytics dashboard on Shopify gives useful business insights.', 'sentiment': {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4404}, 'entities': [], 'key_themes': ['the', 'analytics', 'dashboard']}
# 88                                                                                           {'text': 'The refund policy on AliExpress needs to be more customer-friendly.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'refund', 'policy']}
# 89                                                                                               {'text': 'My Paytm transaction got stuck due to verification delays.', 'sentiment': {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.25}, 'entities': [], 'key_themes': ['my', 'paytm', 'transaction']}
# 90                                                                                          {'text': 'The responsiveness of the Tesla autopilot feature is incredible.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'responsiveness', 'of']}
# 91                                                                                        {'text': 'The navigation features in Google Maps helped me during my trip.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'navigation', 'features']}
# 92                                                                                          {'text': 'My reservation with Booking.com was canceled without notification.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['my', 'reservation', 'with']}
# 93                                                                                      {'text': 'The discounts on Priceline hotel bookings saved me a lot of money.', 'sentiment': {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.4215}, 'entities': [], 'key_themes': ['the', 'discounts', 'on']}
# 94                                                                                                        {'text': 'The performance of my Intel-powered laptop is smooth.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'performance', 'of']}
# 95                                                                                           {'text': 'The smartwatch collection at Fossil offers stylish designs.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'smartwatch', 'collection']}
# 96                                                                                                       {'text': 'The cloud storage features in OneDrive are secure.', 'sentiment': {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.34}, 'entities': [], 'key_themes': ['the', 'cloud', 'storage']}
# 97                                                                               {'text': 'The delivery tracking on FedEx’s website is real-time and efficient.', 'sentiment': {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215}, 'entities': [], 'key_themes': ['the', 'delivery', 'tracking']}
# 98                                                                                                  {'text': 'The Twitter algorithm shows me relevant trending topics.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [], 'key_themes': ['the', 'twitter', 'algorithm']}
# 99                                        {'text': 'My 4G connection on Jio telecom dropped frequently in rural areas.', 'sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, 'entities': [('4g connection', 'QUANTITY'), ('jio telecom', 'ORG')], 'key_themes': ['my', '4g', 'connection']}
