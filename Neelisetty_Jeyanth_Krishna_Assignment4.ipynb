# %%
import os
import spacy
from transformers import pipeline, AutoTokenizer, AutoModel

# %%
# Access Token
os.environ["HF_TOKEN"] = "xxxxxxxxxxxx" # replace with original token

# Load spaCy model for POS tagging
nlp = spacy.load("en_core_web_sm")

# Load a generative AI model from Hugging Face
story_generator = pipeline("text-generation", model="distilgpt2")

# Load a sentence embedding model
embedding_model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Device set to use cpu

# %%
def generate_story(prompt):
    """Generate a 100-word story using Hugging Face GenAI."""
    response = story_generator(f"Write a 100-word story about {prompt}", max_length=150, do_sample=True, truncation=True)
    return response[0]["generated_text"]

def get_embeddings(text):
    """Convert the story into vector format using Hugging Face embeddings."""
    inputs = tokenizer(text, return_tensors="pt")
    outputs = embedding_model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).tolist()

def analyze_parts_of_speech(text):
    """Extract parts of speech from the generated story."""
    doc = nlp(text)
    return [(token.text, token.pos_) for token in doc]

# %%
# because of the compute limitations going for distilgpt2, if compute supports we can replace it with any available model from hugging face.
# Example usage
prompt = "traveller and his bike"
story = generate_story(prompt)
embeddings = get_embeddings(story)
pos_tags = analyze_parts_of_speech(story)

print("Generated Story:\n", story)
print("\nEmbeddings:\n", embeddings)
print("\nParts of Speech:\n", pos_tags)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Story:
#  Write a 100-word story about traveller and his bike, but there’t many people who read a story from a local newspaper or can‭t get over it. This may be a huge concern, for a non-Canadian.
#
#
#
# But when they did read a story about a guy walking to a bus stop, they are not surprised that the guy has not been given the courtesy of the city where he is riding.
# Story continues below advertisement
#
#
#
# Why not make some kind of request at a transit agency, or through a municipal agency like Toronto for a list of names of people they would like to know.
# If, however, an agency chooses to ask the mayor to say whether or not the mayor
#
# Embeddings:
#  [[0.2203139364719391, 0.14144070446491241, 0.11301438510417938, 0.06054045259952545, 0.03456949442625046, 0.014787488617002964, 0.22012414038181305, -0.008115844801068306, -0.08129043132066727, 0.015465669333934784, 0.05326495319604874, 0.07651470601558685, 0.07813966274261475, 0.10592029988765717, -0.10283050686120987, 0.08765916526317596, 0.2247285395860672, 0.228918194770813, -0.01868012361228466, 0.04737114906311035, 0.06478485465049744, 0.0606914684176445, 0.06939821690320969, 0.0961698666214943, -0.04726008325815201, -0.12479245662689209, -0.05451595410704613, -0.009411890059709549, -0.06102629750967026, 0.12615877389907837, -0.1098414808511734, 0.08864936232566833, 0.04051525518298149, 0.07899104803800583, 0.002745050238445401, -0.10022834688425064, -0.11517808586359024, 0.0469326488673687, 0.07252023369073868, -0.0814390629529953, 0.08973643183708191, -0.10065530240535736, -0.06497064977884293, 0.079513780772686, 0.138031005859375, -0.07100770622491837, 0.02871485985815525, 0.12741950154304504, -0.04212898015975952, 0.01950199529528618, -0.04338237643241882, -0.026832126080989838, 0.07713603973388672, -0.22272424399852753, -0.08971114456653595, -0.10396748781204224, -0.0729890763759613, 0.0370938740670681, 0.008030309341847897, -0.03078940324485302, -0.09130760282278061, -0.11835536360740662,
#  [('Write', 'VERB'), ('a', 'DET'), ('100', 'NUM'), ('-', 'PUNCT'), ('word', 'NOUN'), ('story', 'NOUN'), ('about', 'ADP'), ('traveller', 'NOUN'), ('and', 'CCONJ'), ('his', 'PRON'), ('bike', 'NOUN'), (',', 'PUNCT'), ('but', 'CCONJ'), ('there’t', 'ADP'), ('many', 'ADJ'), ('people', 'NOUN'), ('who', 'PRON'), ('read', 'VERB'), ('a', 'DET'), ('story', 'NOUN'), ('from', 'ADP'), ('a', 'DET'), ('local', 'ADJ'), ('newspaper', 'NOUN'), ('or', 'CCONJ'), ('can\u202dt', 'PROPN'), ('get', 'VERB'), ('over', 'ADP'), ('it', 'PRON'), ('.', 'PUNCT'), ('This', 'PRON'), ('may', 'AUX'), ('be', 'AUX'), ('a', 'DET'), ('huge', 'ADJ'), ('concern', 'NOUN'), (',', 'PUNCT'), ('for', 'ADP'), ('a', 'DET'), ('non', 'ADJ'), ('-', 'ADJ'), ('Canadian', 'ADJ'), ('.', 'PUNCT'), ('\n\n\n\n', 'SPACE'), ('But', 'CCONJ'), ('when', 'SCONJ'), ('they', 'PRON'), ('did', 'AUX'), ('read', 'VERB'), ('a', 'DET'), ('story', 'NOUN'), ('about', 'ADP'), ('a', 'DET'), ('guy', 'NOUN'), ('walking', 'VERB'), ('to', 'ADP'), ('a', 'DET'), ('bus', 'NOUN'), ('stop', 'NOUN'), (',', 'PUNCT'), ('they', 'PRON'), ('are', 'AUX'), ('not', 'PART'), ('surprised', 'ADJ'), ('that', 'SCONJ'), ('the', 'DET'), ('guy', 'NOUN'), ('has', 'AUX'), ('not', 'PART'), ('been', 'AUX'), ('given', 'VERB'), ('the', 'DET'), ('courtesy', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('city', 'NOUN'), ('where', 'SCONJ'), ('he', 'PRON'), ('is', 'AUX'), ('riding', 'VERB'), ('.', 'PUNCT'), ('\n', 'SPACE'), ('Story', 'PROPN'), ('continues', 'VERB'), ('below', 'ADP'), ('advertisement', 'NOUN'), ('\n\n\n\n', 'SPACE'), ('Why', 'SCONJ'), ('not', 'PART'), ('make', 'VERB'), ('some', 'DET'), ('kind', 'NOUN'), ('of', 'ADP'), ('request', 'NOUN'), ('at', 'ADP'), ('a', 'DET'), ('transit', 'NOUN'), ('agency', 'NOUN'), (',', 'PUNCT'), ('or', 'CCONJ'), ('through', 'ADP'), ('a', 'DET'), ('municipal', 'ADJ'), ('agency', 'NOUN'), ('like', 'ADP'), ('Toronto', 'PROPN'), ('for', 'ADP'), ('a', 'DET'), ('list', 'NOUN'), ('of', 'ADP'), ('names', 'NOUN'), ('of', 'ADP'), ('people', 'NOUN'), ('they', 'PRON'), ('would', 'AUX'), ('like', 'VERB'), ('to', 'PART'), ('know', 'VERB'), ('.', 'PUNCT'), ('\n', 'SPACE'), ('If', 'SCONJ'), (',', 'PUNCT'), ('however', 'ADV'), (',', 'PUNCT'), ('an', 'DET'), ('agency', 'NOUN'), ('chooses', 'VERB'), ('to', 'PART'), ('ask', 'VERB'), ('the', 'DET'), ('mayor', 'NOUN'), ('to', 'PART'), ('say', 'VERB'), ('whether', 'SCONJ'), ('or', 'CCONJ'), ('not', 'PART'), ('the', 'DET'), ('mayor', 'NOUN')]
